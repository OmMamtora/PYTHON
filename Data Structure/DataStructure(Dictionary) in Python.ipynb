# %%
d={'a':'apple','b':'ball'}
num = {1:22,3:10,5:60}

# %%
d['a']
num[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 d['a']
#       2 num[1]
#
# KeyError: 'a'

# %% [markdown]
# ## Creating Dictionary using dict() function:

# %%
data = ([1,56],[2,49],[7,67])

d= dict(data)

# %%
d
# Out:
# {1: 56, 2: 49, 7: 67}

# %%
animals = {}

animals[1] =' Dog'
animals[2] = 'Cat'
animals[3] = 'Cow'

# %%
animals
# Out:
# {1: ' Dog', 2: 'Cat', 3: 'Cow'}

# %% [markdown]
# ## Methods in list

# %%
animals.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
animals.values()
# Out:
# dict_values([' Dog', 'Cat', 'Cow'])

# %%
animals.items()
# Out:
# dict_items([(1, ' Dog'), (2, 'Cat'), (3, 'Cow')])

# %%
animals.get(3) # it take 2 argument but it is not compulsory to give 2nd parameter
# Out:
# 'Cow'

# %%
animals.clear()

# %%
animals
# Out:
# {}

# %%
animals.get(5,6)
# Out:
# 6
