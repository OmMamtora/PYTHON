# %%
num = int(input("Enter Number:->"))
octal = ""

while num > 0:
    digit = num % 8
    octal = str(digit) + octal
    num //= 8
        
print("Octal ",octal)


# 34 % 8 = 2 → octal = "2"
# 34 // 8 = 4
# 4 % 8 = 4 → octal = "4" + "2" = "42"
# Out:
# Enter Number:->34
# Octal  42

# %%
num = int(input("Enter Number:->"))
octal = ""
binary = ""

while num > 0:
    digit = num % 2
    binary = str(digit) + binary
    num //=2
        
print("binary ",binary)
# Out:
# Enter Number:->34
# binary  100010

# %%
lst = []
topper = ()
max_marks = -1  # use -1 to ensure any positive mark will be greater

for i in range(3):
    roll_No = int(input("Enter Roll No. :-> "))
    name = input("Enter Name :-> ")
    marks = int(input("Enter Marks :-> "))

    student = (roll_No, name, marks)
    lst.append(student)

    if marks > max_marks:
        max_marks = marks
        topper = student  # store the whole record

print("\nAll Student Records:")
for record in lst:
    print(record)

print("\nTopper is:")
print(f"Roll No: {topper[0]}, Name: {topper[1]}, Marks: {topper[2]}")
# Out:
# Enter Roll No. :-> 1
# Enter Name :-> dgd
# Enter Marks :-> 45
# Enter Roll No. :-> 2
# Enter Name :-> t
# Enter Marks :-> 456
# Enter Roll No. :-> 3
# Enter Name :-> rty
# Enter Marks :-> 56
#
# All Student Records:
# (1, 'dgd', 45)
# (2, 't', 456)
# (3, 'rty', 56)
#
# Topper is:
# Roll No: 2, Name: t, Marks: 456

# %%
lst = []
max_marks = 0
rec=()

for i in range(3):
    roll_No = int(input("Enter Roll No. :-> "))
    name = input("Enter Name :-> ")
    marks = int(input("Enter Marks :-> "))
    
    lst.append((roll_No,name,marks))
    
    if marks > max_marks:
        max_marks = marks
        rec = (roll_No, name, marks)
        
print("\nAll Student Records:")
for record in lst:
    print(record)

print("\nTopper is:")
print(f"Roll No: {rec[0]}, Name: {rec[1]}, Marks: {rec[2]}")
# std_data=tuple(lst)

# print(std_data)

# print(std_data[0][2])

# maximum = std_data[0]

# for j in maximum:
#     xyz = max(std_data[j][2])
#     print(xyz)
# Out:
# Enter Roll No. :-> 1
# Enter Name :-> dfgf
# Enter Marks :-> 345
# Enter Roll No. :-> 2
# Enter Name :-> thyt
# Enter Marks :-> 54
# Enter Roll No. :-> 3
# Enter Name :-> ertr
# Enter Marks :-> 456
#
# All Student Records:
# (1, 'dfgf', 345)
# (2, 'thyt', 54)
# (3, 'ertr', 456)
#
# Topper is:
# Roll No: 3, Name: ertr, Marks: 456

# %%
# Create a Python program to read n strings from user, store them into list. Display only those strings which is having even 
# length

n = int(input("How many string do you want to add?"))

same_string = []

for i in range(n):
    string = input("Enter String:->")
    same_string.append(string)
for char in same_string:
    if len(char) %2 == 0:
        print(char)

# %%
n = int(input("How many strings do you want to add? "))

string_list = []

for i in range(n):
    s = input(f"Enter string {i+1}: ")
    string_list.append(s)

print("\nStrings with even length:")
for word in string_list:
    if len(word) % 2 == 0:
        print(word)
